# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

import os

# %% [markdown]
# # DATA Representation and Description

# %%
heart = pd.read_csv('C:/Users/KIIT/Desktop/heart stroke prediction/heart_failure_clinical_records_dataset.csv')
heart
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# ...

# %%
heart.describe(include='all')
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   gender                    299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  STROKES                   299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
heart.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# gender                      0
# smoking                     0
# time                        0
# STROKES                     0
# dtype: int64

# %%
heart.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time',
#        'STROKES'],
#       dtype='object')

# %% [markdown]
# # Data Preprossessing

# %%
from sklearn.preprocessing import MinMaxScaler #Normalizing data
sc = MinMaxScaler()
heart = pd.DataFrame(sc.fit_transform(heart),columns = heart.columns)
heart
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.636364      0.0                  0.071319       0.0           0.090909
# 1    0.272727      0.0                  1.000000       0.0           0.363636
# 2    0.454545      0.0                  0.015693       0.0           0.090909
# 3    0.181818      1.0                  0.011227       0.0           0.090909
# 4    0.454545      1.0                  0.017479       1.0           0.090909
# ..        ...      ...                       ...       ...                ...
# 294  0.400000      0.0                  0.004848       1.0           0.363636
# 295  0.272727      0.0                  0.229268       0.0           0.363636
# 296  0.090909      0.0                  0.259888       1.0           0.696970
# 297  0.090909      0.0                  0.304925       0.0           0.363636
# 298  0.181818      0.0                  0.022072       0.0           0.469697
#
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(heart, hue = 'STROKES')

# %%
display(heart[['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time',
       'STROKES']].groupby([ 'gender','smoking', 'smoking','high_blood_pressure', 'diabetes','anaemia']).agg(['max','mean','min']).style.background_gradient('Oranges'))
# Out:
# <style  type="text/css" >
# #T_db826_row0_col0,#T_db826_row5_col6{
#             background-color:  #c54102;
#             color:  #f1f1f1;
#         }#T_db826_row0_col1,#T_db826_row21_col20{
#             background-color:  #f4711c;
#             color:  #000000;
#         }#T_db826_row0_col2,#T_db826_row0_col11,#T_db826_row0_col14,#T_db826_row3_col2,#T_db826_row12_col2,#T_db826_row21_col2,#T_db826_row21_col14,#T_db826_row26_col14,#T_db826_row27_col14{
#             background-color:  #ffeedd;
#             color:  #000000;
#         }#T_db826_row0_col3,#T_db826_row3_col12,#T_db826_row8_col0,#T_db826_row10_col18,#T_db826_row21_col12,#T_db826_row25_col3{
#             background-color:  #fdd5ad;
#             color:  #000000;
#         }#T_db826_row0_col4,#T_db826_row3_col1,#T_db826_row4_col3,#T_db826_row14_col12,#T_db826_row24_col12{
#             background-color:  #fdbf86;
#             color:  #000000;
# ...

# %%
corr = heart.corr()
plt.figure(figsize = (30,12))
sns.heatmap(corr,vmax =1 ,vmin = -1,linewidth = 5, square =True, annot =True ,annot_kws ={'size':8},fmt ='.1f',cmap='BrBG_r')
plt.title('Correlation')
plt.show()

# %% [markdown]
# # Spliting The Data

# %%
X = heart[['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'gender', 'smoking', 'time']]
y = heart['STROKES']
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 294    0.0
# 295    0.0
# 296    0.0
# 297    0.0
# 298    0.0
# Name: STROKES, Length: 299, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size =0.2,random_state = 2)

# %%
X_train.shape
# Out:
# (239, 12)

# %%
y_train.shape
# Out:
# (239,)

# %%
X_test.shape
# Out:
# (60, 12)

# %%
y_train
# Out:
# 53     1.0
# 172    0.0
# 23     0.0
# 98     0.0
# 244    0.0
#       ...
# 75     1.0
# 22     1.0
# 72     1.0
# 15     1.0
# 168    0.0
# Name: STROKES, Length: 239, dtype: float64

# %%
y_test.shape
# Out:
# (60,)

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train) #Logistic Regression.
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
yhat = model.predict(X_test)
accuracy_score(y_test,yhat)
# Out:
# 0.9

# %%
from sklearn.tree import DecisionTreeClassifier
model1 = DecisionTreeClassifier(criterion = 'entropy', random_state= 0)
model1.fit(X_train,y_train) # Decision Tree
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_hat1 = model1.predict(X_test)
accuracy_score(y_test,y_hat1)
# Out:
# 0.9

# %%
from sklearn.naive_bayes import GaussianNB
model2 = GaussianNB()
model2.fit(X_train,y_train) #Naive Bayes:
# Out:
# GaussianNB()

# %%
yhat2 = model2.predict(X_test)
accuracy_score(y_test,yhat2)
# Out:
# 0.7666666666666667
